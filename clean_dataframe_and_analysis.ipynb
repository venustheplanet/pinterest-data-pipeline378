# %%
from pyspark.sql.functions import *
import urllib
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Clean df_pin

# %%
data_pin = spark.read.json("/mnt/s3bucket-121ca9f7ce2b/topics/121ca9f7ce2b.pin/partition=0/*.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cleaned_df_pin = data_pin.replace({"": None})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Replace entries with no relevant data with None

unrelevant_data = {
    "description": "No description available Story format",
    "description": "No description available",
    "follower_count": "User Info Error",
    "image_src": "Image src error.",
    "poster_name": "User Info Error",
    "tag_list": "N,o, ,T,a,g,s, ,A,v,a,i,l,a,b,l,e",
    "title": "No Title Data Available"
}

for col, data in unrelevant_data.items():
    cleaned_df_pin = cleaned_df_pin.replace({data: None}, subset=[col])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Cast follower_count to int, removing of 'K' and 'M'

cleaned_df_pin = cleaned_df_pin.withColumn("follower_count", regexp_replace("follower_count", "k", "000"))
cleaned_df_pin = cleaned_df_pin.withColumn("follower_count", regexp_replace("follower_count", "M", "000000"))
cleaned_df_pin = cleaned_df_pin.withColumn("follower_count", cleaned_df_pin["follower_count"].cast('int'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Only save location path in save_location

cleaned_df_pin = cleaned_df_pin.withColumn("save_location", regexp_replace("save_location", "Local save in ", ""))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Rename index column to ind

cleaned_df_pin = cleaned_df_pin.withColumnRenamed("index", "ind")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Reorder columns

cleaned_df_pin = cleaned_df_pin.select("ind", "unique_id", "title", "description", "follower_count", "poster_name", "tag_list", "is_image_or_video", "image_src", "save_location", "category")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cleaned_df_pin.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ind: long (nullable = true)
# -- unique_id: string (nullable = true)
# -- title: string (nullable = true)
# -- description: string (nullable = true)
# -- follower_count: integer (nullable = true)
# -- poster_name: string (nullable = true)
# -- tag_list: string (nullable = true)
# -- is_image_or_video: string (nullable = true)
# -- image_src: string (nullable = true)
# -- save_location: string (nullable = true)
# -- category: string (nullable = true)
#
# </div>

# %% [markdown]
# #### Clean df_geo

# %%
df_geo = spark.read.json("/mnt/s3bucket-121ca9f7ce2b/topics/121ca9f7ce2b.geo/partition=0/*.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create new column that combines latitude and longitude in an array

cleaned_df_geo = df_geo.withColumn("coordinates", array("latitude", "longitude"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Drop latitude and longitude 
cleaned_df_geo = cleaned_df_geo.drop("latitude", "longitude")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Convert timestamp column from string to a timestamp data type
cleaned_df_geo = cleaned_df_geo.withColumn("timestamp", to_timestamp("timestamp"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Reorder the columns
cleaned_df_geo = cleaned_df_geo.select("ind", "country", "coordinates", "timestamp")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cleaned_df_geo.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ind: long (nullable = true)
# -- country: string (nullable = true)
# -- coordinates: array (nullable = false)
#     |-- element: double (containsNull = true)
# -- timestamp: timestamp (nullable = true)
#
# </div>

# %% [markdown]
# #### Clean df_user

# %%
df_user = spark.read.json("/mnt/s3bucket-121ca9f7ce2b/topics/121ca9f7ce2b.user/partition=0/*.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Combine first name and last name

cleaned_df_user = df_user.withColumn("user_name", concat("first_name", lit(" "), "last_name"))
cleaned_df_user = cleaned_df_user.drop("first_name", "last_name")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Convert date_joined to timestamp

cleaned_df_user = cleaned_df_user.withColumn("date_joined", to_timestamp("date_joined"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Reorder dataframe

cleaned_df_user = cleaned_df_user.select("ind", "user_name", "age", "date_joined")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cleaned_df_user.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ind: long (nullable = true)
# -- user_name: string (nullable = true)
# -- age: long (nullable = true)
# -- date_joined: timestamp (nullable = true)
#
# </div>

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# #### Find the most popular category in each country

# %%
# Joining df_pin and df_geo based on 'ind'

pin_geo = cleaned_df_pin.join(cleaned_df_geo, cleaned_df_geo["ind"] == cleaned_df_pin["ind"], how="inner")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.window import *

cat_country = pin_geo.select("country", "category")
# window_spec = Window.partitionBy("country").orderBy("category_count")
result_cat_country = cat_country.groupBy("country", "category").agg(count("category").alias("category_count"))
window_spec = Window.partitionBy("country").orderBy(desc("category_count"))

result_cat_country = result_cat_country.withColumn("rank", row_number().over(window_spec))
result_cat_country = result_cat_country.filter(result_cat_country["rank"] == 1).drop("rank")
display(result_cat_country)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>category</th><th>category_count</th></tr></thead><tbody><tr><td>Afghanistan</td><td>education</td><td>55</td></tr><tr><td>Albania</td><td>art</td><td>64</td></tr><tr><td>Algeria</td><td>quotes</td><td>113</td></tr><tr><td>American Samoa</td><td>tattoos</td><td>40</td></tr><tr><td>Andorra</td><td>tattoos</td><td>30</td></tr><tr><td>Angola</td><td>diy-and-crafts</td><td>18</td></tr><tr><td>Anguilla</td><td>diy-and-crafts</td><td>17</td></tr><tr><td>Antarctica (the territory South of 60 deg S)</td><td>christmas</td><td>18</td></tr><tr><td>Antigua and Barbuda</td><td>christmas</td><td>24</td></tr><tr><td>Argentina</td><td>tattoos</td><td>46</td></tr><tr><td>Armenia</td><td>diy-and-crafts</td><td>30</td></tr><tr><td>Aruba</td><td>tattoos</td><td>42</td></tr><tr><td>Australia</td><td>christmas</td><td>16</td></tr><tr><td>Austria</td><td>travel</td><td>17</td></tr><tr><td>Azerbaijan</td><td>finance</td><td>21</td></tr><tr><td>Bahamas</td><td>art</td><td>32</td></tr><tr><td>Bahrain</td><td>finance</td><td>16</td></tr><tr><td>Bangladesh</td><td>christmas</td><td>27</td></tr><tr><td>Barbados</td><td>travel</td><td>17</td></tr><tr><td>Belarus</td><td>travel</td><td>8</td></tr><tr><td>Belgium</td><td>diy-and-crafts</td><td>12</td></tr><tr><td>Belize</td><td>diy-and-crafts</td><td>17</td></tr><tr><td>Benin</td><td>travel</td><td>8</td></tr><tr><td>Bermuda</td><td>christmas</td><td>15</td></tr><tr><td>Bhutan</td><td>event-planning</td><td>14</td></tr><tr><td>Bolivia</td><td>diy-and-crafts</td><td>14</td></tr><tr><td>Bosnia and Herzegovina</td><td>christmas</td><td>9</td></tr><tr><td>Botswana</td><td>tattoos</td><td>29</td></tr><tr><td>Bouvet Island (Bouvetoya)</td><td>diy-and-crafts</td><td>12</td></tr><tr><td>Brazil</td><td>finance</td><td>7</td></tr><tr><td>British Indian Ocean Territory (Chagos Archipelago)</td><td>tattoos</td><td>4</td></tr><tr><td>British Virgin Islands</td><td>christmas</td><td>15</td></tr><tr><td>Brunei Darussalam</td><td>diy-and-crafts</td><td>5</td></tr><tr><td>Bulgaria</td><td>christmas</td><td>23</td></tr><tr><td>Burkina Faso</td><td>quotes</td><td>15</td></tr><tr><td>Burundi</td><td>mens-fashion</td><td>14</td></tr><tr><td>Cambodia</td><td>diy-and-crafts</td><td>9</td></tr><tr><td>Cameroon</td><td>art</td><td>8</td></tr><tr><td>Canada</td><td>travel</td><td>5</td></tr><tr><td>Cape Verde</td><td>education</td><td>9</td></tr><tr><td>Cayman Islands</td><td>travel</td><td>4</td></tr><tr><td>Central African Republic</td><td>mens-fashion</td><td>9</td></tr><tr><td>Chad</td><td>diy-and-crafts</td><td>5</td></tr><tr><td>Chile</td><td>mens-fashion</td><td>6</td></tr><tr><td>China</td><td>beauty</td><td>4</td></tr><tr><td>Christmas Island</td><td>travel</td><td>11</td></tr><tr><td>Cocos (Keeling) Islands</td><td>vehicles</td><td>9</td></tr><tr><td>Colombia</td><td>finance</td><td>21</td></tr><tr><td>Comoros</td><td>quotes</td><td>5</td></tr><tr><td>Congo</td><td>art</td><td>19</td></tr><tr><td>Cook Islands</td><td>travel</td><td>4</td></tr><tr><td>Costa Rica</td><td>christmas</td><td>10</td></tr><tr><td>Cote d'Ivoire</td><td>diy-and-crafts</td><td>10</td></tr><tr><td>Croatia</td><td>finance</td><td>13</td></tr><tr><td>Cuba</td><td>diy-and-crafts</td><td>6</td></tr><tr><td>Cyprus</td><td>home-decor</td><td>5</td></tr><tr><td>Czech Republic</td><td>travel</td><td>8</td></tr><tr><td>Denmark</td><td>beauty</td><td>16</td></tr><tr><td>Djibouti</td><td>diy-and-crafts</td><td>6</td></tr><tr><td>Dominica</td><td>event-planning</td><td>5</td></tr><tr><td>Dominican Republic</td><td>home-decor</td><td>20</td></tr><tr><td>Ecuador</td><td>mens-fashion</td><td>8</td></tr><tr><td>Egypt</td><td>home-decor</td><td>9</td></tr><tr><td>El Salvador</td><td>quotes</td><td>4</td></tr><tr><td>Equatorial Guinea</td><td>travel</td><td>4</td></tr><tr><td>Eritrea</td><td>diy-and-crafts</td><td>1</td></tr><tr><td>Esto ...

# %% [markdown]
# #### Find the most popular category each year between 2018 and 2022

# %%
# Create window spec

# filter out year between 2018 and 2022
cat_year = pin_geo.filter((year("timestamp") >= 2018) & (year("timestamp") <= 2022))\
    .withColumn("post_year", year("timestamp"))\
    .select("post_year", "category")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(cat_year)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>post_year</th><th>category</th></tr></thead><tbody><tr><td>2020</td><td>event-planning</td></tr><tr><td>2022</td><td>home-decor</td></tr><tr><td>2022</td><td>home-decor</td></tr><tr><td>2022</td><td>home-decor</td></tr><tr><td>2022</td><td>home-decor</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2018</td><td>home-decor</td></tr><tr><td>2020</td><td>christmas</td></tr><tr><td>2018</td><td>diy-and-crafts</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2019</td><td>education</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2018</td><td>christmas</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2022</td><td>quotes</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>event-planning</td></tr><tr><td>2020</td><td>home-decor</td></tr><tr><td>2020</td><td>home-decor</td></tr><tr><td>2020</td><td>home-decor</td></tr><tr><td>2020</td><td>home-decor</td></tr><tr><td>2018</td><td>diy-and-crafts</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2018</td><td>vehicles</td></tr><tr><td>2018</td><td>vehicles</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2018</td><td>vehicles</td></tr><tr><td>2018</td><td>vehicles</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2021</td><td>event-planning</td></tr><tr><td>2020</td><td>christmas</td></tr><tr><td>2019</td><td>mens-fashion</td></tr><tr><td>2020</td><td>art</td></tr><tr><td>2020</td><td>art</td></tr><tr><td>2020</td><td>art</td></tr><tr><td>2020</td><td>art</td></tr><tr><td>2019</td><td>art</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2021</td><td>diy-and-crafts</td></tr><tr><td>2018</td><td>tattoos</td></tr><tr><td>2020</td><td>event-planning</td></tr><tr><td>2020</td><td>event-planning</td></tr><tr><td>2020</td><td>event-planning</td></tr><tr><td>2020</td><td>event-planning</td></tr><tr><td>2022</td><td>vehicles</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2022</td><td>vehicles</td></tr><tr><td>2022</td><td>education</td></tr><tr><td>2022</td><td>christmas</td></tr><tr><td>2018</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2019</td><td>tattoos</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2019</td><td>christmas</td></tr><tr><td>2020</td><td>christmas</td></tr><tr><td>2022</td><td>event-planning</td></tr><tr><td>2022</td><td>event-planning</td></tr><tr><td>2022</td><td>event-planning</td></tr><tr><td>2022</td><td>event-planning</td></tr><tr><td>2020</td><td>christmas</td></tr><tr><td>2019</td><td>finance</td></tr><tr><td>2022</td><td>christmas</td></tr><tr><td>2020</td><td>christmas</td></tr><tr><td>2021</td><td>art</td></tr><tr><td>2021</td><td>art</td></tr><tr><td>2021</td><td>art</td></tr><tr><td>2021</td><td>art</td></tr><tr><td>2018</td><td>event-planning</td></tr><tr><td>2020</td><td>finance</td></tr><tr><td>2020</td><td>event-planning</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2021</td><td>christmas</td></tr><tr><td>2019</td><td>event-pl ...

# %%
# Create window spec partition by 'post_year' and order by 'category_count'
window_spec = Window.partitionBy("post_year").orderBy(desc("category_count"))

# Get category count for each year and category
result_cat_year = cat_year.groupBy("post_year", "category").agg(count("category").alias("category_count"))\
    .withColumn("rank", row_number().over(window_spec))\
    .filter("rank = 1")\
    .drop("rank")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_cat_year.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------------+--------------+
# post_year|      category|category_count|
# +---------+--------------+--------------+
#      2018|diy-and-crafts|           113|
#      2019|diy-and-crafts|           105|
#      2020|  mens-fashion|           121|
#      2021|           art|           124|
#      2022|     christmas|           119|
# +---------+--------------+--------------+
#
# </div>

# %% [markdown]
# #### User With Most Followers Per Country

# %%
# Find the max follower count for each country 

follower_country = pin_geo.groupBy("country").agg(
    max("follower_count").alias("follower_count"), 
    first("poster_name").alias("poster_name"))
    

follower_country.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- country: string (nullable = true)
# -- follower_count: integer (nullable = true)
# -- poster_name: string (nullable = true)
#
# </div>

# %%
# Find the country with the user with most followers

result_user_most_fol = follower_country.orderBy(desc("follower_count"))\
    .select(first("country").alias("country"), first("follower_count").alias("follower_count")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+--------------+
#  country|follower_count|
# +--------+--------------+
# Anguilla|      15000000|
# +--------+--------------+
#
# </div>

# %%
pin_geo.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ind: long (nullable = true)
# -- unique_id: string (nullable = true)
# -- title: string (nullable = true)
# -- description: string (nullable = true)
# -- follower_count: integer (nullable = true)
# -- poster_name: string (nullable = true)
# -- tag_list: string (nullable = true)
# -- is_image_or_video: string (nullable = true)
# -- image_src: string (nullable = true)
# -- save_location: string (nullable = true)
# -- category: string (nullable = true)
# -- ind: long (nullable = true)
# -- country: string (nullable = true)
# -- coordinates: array (nullable = false)
#     |-- element: double (containsNull = true)
# -- timestamp: timestamp (nullable = true)
#
# </div>

# %% [markdown]
# #### The most popular category for different age groups
#
# - 18-24
# - 25-35
# - 36-50
# - +50

# %%
# Inner join df_pin and df_user on 'ind'

pin_user = cleaned_df_pin.join(cleaned_df_user, cleaned_df_user["ind"] == cleaned_df_pin["ind"], how="inner")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create new column based on age group
cat_age_group = pin_user.withColumn(
    "age_group",
    when((col("age") >= 18) & (col("age") < 25), "18-24")
    .when((col("age") >= 25) & (col("age") < 36), "25-35")
    .when((col("age") >= 36) & (col("age") < 51), "36-50")
    .when(col("age") > 50, "+50")
).select("age_group", "category")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create window spec
age_cat_window = Window.partitionBy("age_group").orderBy(desc("category_count"))

# group by age_group and category
result_cat_age = cat_age_group.groupBy("age_group", "category").agg(count("category").alias("category_count"))\
    .withColumn("rank", rank().over(age_cat_window))\
    .filter("rank = 1")\
    .drop("rank")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
result_cat_age.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------+--------------+
# age_group|category|category_count|
# +---------+--------+--------------+
#       +50|  beauty|            59|
#     18-24| tattoos|           281|
#     25-35|  travel|           174|
#     36-50|  quotes|           110|
# +---------+--------+--------------+
#
# </div>

# %% [markdown]
# #### Find the Median Follower Count for Different Age Groups

# %%
# Create new column based on age group and select 'follower_count'
follower_age_group = pin_user.withColumn(
    "age_group",
    when((col("age") >= 18) & (col("age") < 25), "18-24")
    .when((col("age") >= 25) & (col("age") < 36), "25-35")
    .when((col("age") >= 36) & (col("age") < 51), "36-50")
    .when(col("age") > 50, "+50")
).select("age_group", "follower_count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
follower_age_group.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age_group: string (nullable = true)
# -- follower_count: integer (nullable = true)
#
# </div>

# %%
# Create window spec partition over age group
window_follower_age = Window.partitionBy("age_group")

# group by age group and find median follower count
median_follower_age_group = follower_age_group.withColumn(
    "median_follower_count",
    percentile_approx("follower_count", 0.5)
    .over(window_follower_age)
).select("age_group", "median_follower_count").distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
median_follower_age_group.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------------------+
# age_group|median_follower_count|
# +---------+---------------------+
#       +50|                  908|
#     18-24|               142000|
#     25-35|                26000|
#     36-50|                 7000|
# +---------+---------------------+
#
# </div>

# %%
# Another approach by using agg percentile
median_follower_age_group2 = follower_age_group.groupBy("age_group").agg(
    expr("percentile(follower_count, 0.5)").alias("median_follower_count")
).select("age_group", "median_follower_count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
median_follower_age_group2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------------------+
# age_group|median_follower_count|
# +---------+---------------------+
#     36-50|               7000.0|
#       +50|                954.0|
#     18-24|             142000.0|
#     25-35|              26000.0|
# +---------+---------------------+
#
# </div>

# %% [markdown]
# #### Find how many users have joined each year between 2015 and 2020

# %%
# create new column of year from date_joined 

user_year = cleaned_df_user.filter((year("date_joined") >= 2015) & (year("date_joined") <= 2020))\
    .withColumn("post_year", year("date_joined"))\
    .select("post_year", "user_name")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
user_year.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- post_year: integer (nullable = true)
# -- user_name: string (nullable = true)
#
# </div>

# %%
num_user_year = user_year.groupBy("post_year").agg(count("user_name").alias("numbers_users_joined"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
num_user_year.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+--------------------+
# post_year|numbers_users_joined|
# +---------+--------------------+
#      2015|                1273|
#      2016|                1429|
#      2017|                 512|
# +---------+--------------------+
#
# </div>

# %%
# Check if there is no user joined after 2017

cleaned_df_user.createOrReplaceTempView("df_user_temp")

year_result = spark.sql("""
SELECT
    YEAR(date_joined) AS post_year,
    user_name
FROM
    df_user_temp
WHERE
    YEAR(date_joined) > 2017
""")

year_result.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+
# post_year|user_name|
# +---------+---------+
# +---------+---------+
#
# </div>

# %% [markdown]
# #### Find the median follower count of users based on their joining year

# %%
# Create year column and select relevant columns

user_year_follower = pin_user.filter((year("date_joined") >= 2015) & (year("date_joined") <= 2020))\
    .withColumn("post_year", year("date_joined"))\
    .select("post_year", "user_name", "follower_count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
median_follower_year = user_year_follower.groupBy("post_year").agg(
    expr("percentile(follower_count, 0.5)").alias("median_follower_count")
).select("post_year", "median_follower_count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
median_follower_year.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------------------+
# post_year|median_follower_count|
# +---------+---------------------+
#      2015|             163000.0|
#      2016|              18000.0|
#      2017|               4000.0|
# +---------+---------------------+
#
# </div>

# %% [markdown]
# #### Find median follower count of users based on their joining year and age group

# %%
# Create age, year columns and select relevant columns

age_year_follower = pin_user.filter((year("date_joined") >= 2015) & (year("date_joined") <= 2020))\
    .withColumn("post_year", year("date_joined"))\
    .withColumn(
    "age_group",
    when((col("age") >= 18) & (col("age") < 25), "18-24")
    .when((col("age") >= 25) & (col("age") < 36), "25-35")
    .when((col("age") >= 36) & (col("age") < 51), "36-50")
    .when(col("age") > 50, "+50")
    )\
    .select("post_year", "age_group", "follower_count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
median_follower_year_age = age_year_follower.groupBy("post_year", "age_group").agg(
    expr("percentile(follower_count, 0.5)").alias("median_follower_count")
).select("post_year","age_group","median_follower_count")\
    .orderBy("post_year", "age_group")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
median_follower_year_age.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+---------------------+
# post_year|age_group|median_follower_count|
# +---------+---------+---------------------+
#      2015|      +50|              14000.0|
#      2015|    18-24|             267000.0|
#      2015|    25-35|              44000.0|
#      2015|    36-50|              11000.0|
#      2016|      +50|                542.0|
#      2016|    18-24|              40000.0|
#      2016|    25-35|              23000.0|
#      2016|    36-50|               9000.0|
#      2017|      +50|               2000.0|
#      2017|    18-24|              10000.0|
#      2017|    25-35|               5500.0|
#      2017|    36-50|               3000.0|
# +---------+---------+---------------------+
#
# </div>
